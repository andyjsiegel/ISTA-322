# %% [markdown]
# For this practice we want to store the Yelp shops and review in MongoDB and use that to run some queries.
# Before starting this notebook, create a yelp dataset on MongoDB, then add reviews and shops collection to it. The notes on Setting up MongoDB show how you can do this.
#
# ** Submission Instruction **
#
# * Make a copy and replace blank with yourname
# * Complete the notebook and run all the cells
# * Download the .ipybn
# * Submit on Gradescope

# %%
# !pip install yelpapi
# !pip install "pymongo[srv]"
# Out:
# Collecting yelpapi
#   Downloading yelpapi-2.5.1-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from yelpapi) (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->yelpapi) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->yelpapi) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->yelpapi) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->yelpapi) (2025.10.5)
# Downloading yelpapi-2.5.1-py3-none-any.whl (7.4 kB)
# Installing collected packages: yelpapi
# Successfully installed yelpapi-2.5.1
# Collecting pymongo[srv]
#   Downloading pymongo-4.15.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# WARNING: pymongo 4.15.3 does not provide the extra 'srv'
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo[srv])
#   Downloading dnspython-2.8.0-py3-none-any.whl.metadata (5.7 kB)
# Downloading dnspython-2.8.0-py3-none-any.whl (331 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 10.8 MB/s eta 0:00:00
# Downloading pymongo-4.15.3-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 57.2 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.8.0 pymongo-4.15.3

# %%
# Libraries
from yelpapi import YelpAPI
import pandas as pd
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

# %%
yelp_api = YelpAPI('')

# %%
#connecting to MongoDB

#change uri with your connection string
uri = "client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
#making sure that shops and review collections have been created!

db = client['yelp']
shops_collection = db['shops']
reviews_collection = db['reviews']

# %% [markdown]
# Let's search for taco shops and store to taco_shops, this time in Illinois

# %%
taco_shops = yelp_api.search_query(term = 'taco',  location = 'IL')

# %% [markdown]
# Let's first check if we got the shops correctly:

# %%
taco_shops['businesses'][0]
# Out:
# {'id': 'CADdsveMbJY-x_PFrsCkQw',
#  'alias': 'el-tragon-taqueria-chicago-5',
#  'name': 'El Tragon Taqueria',
#  'image_url': 'https://s3-media0.fl.yelpcdn.com/bphoto/EANG1s0BojybA2qEx0w7Iw/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/el-tragon-taqueria-chicago-5?adjust_creative=xa8hs_B5jAwIuyuEtG_r0g&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=xa8hs_B5jAwIuyuEtG_r0g',
#  'review_count': 160,
#  'categories': [{'alias': 'tacos', 'title': 'Tacos'}],
#  'rating': 4.7,
#  'coordinates': {'latitude': 41.904700405779366,
#   'longitude': -87.64861798544506},
#  'transactions': ['pickup', 'delivery'],
#  'location': {'address1': '1234 N Halsted St',
#   'address2': 'Unit C',
#   'address3': '',
#   'city': 'Chicago',
#   'zip_code': '60642',
#   'country': 'US',
#   'state': 'IL',
#   'display_address': ['1234 N Halsted St', 'Unit C', 'Chicago, IL 60642']},
#  'phone': '+13123741458',
#  'display_phone': '(312) 374-1458',
#  'distance': 2412.6555644337254,
#  'business_hours': [{'open': [{'is_overnight': False,
#      'start': '1000',
#      'end': '2000',
#      'day': 0},
#     {'is_overnight': False, 'start': '1000', 'end': '2000', 'day': 1},
#     {'is_overnight': False, 'start': '1000', 'end': '2000', 'day': 2},
#     {'is_overnight': False, 'start': '1000', 'end': '2000', 'day': 3},
#     {'is_overnight': False, 'start': '1000', 'end': '2000', 'day': 4},
#     {'is_overnight': False, 'start': '1000', 'end': '1600', 'day': 5}],
#    'hours_type': 'REGULAR',
#    'is_open_now': True}],
#  'attributes': {'business_accepts_android_pay': True,
#   'business_accepts_apple_pay': True,
#   'business_url': 'http://www.eltragontaqueria.com',
#   'about_this_biz_bio_photo_dict': None,
#   'about_this_biz_business_recommendation': [],
#   'business_temp_closed': None,
#   'about_this_biz_bio': None,
#   'about_this_biz_bio_first_name': None,
#   'about_this_biz_bio_last_name': None,
#   'about_this_biz_history': "We are the newest taco place in the city and we get out inspiration from the small street taco vendors in Jalisco's Highlands region. Come and try us!",
#   'about_this_biz_role': None,
#   'about_this_biz_specialties': None,
#   'about_this_biz_year_established': '2021',
#   'alcohol': 'none',
#   'ambience': {'divey': None,
#    'hipster': None,
#    'casual': True,
#    'touristy': False,
#    'trendy': None,
#    'intimate': None,
#    'romantic': False,
#    'classy': False,
#    'upscale': False},
#   'bike_parking': True,
#   'business_accepts_credit_cards': True,
#   'business_parking': {'valet': False,
#    'garage': True,
#    'street': False,
#    'lot': False,
#    'validated': True},
#   'caters': True,
#   'dogs_allowed': True,
#   'drive_thru': False,
#   'good_for_kids': None,
#   'good_for_meal': None,
#   'happy_hour': None,
#   'has_tv': False,
#   'menu_url': 'http://www.eltragontaqueria.com/menus',
#   'noise_level': 'average',
#   'open24_hours': None,
#   'platform_delivery': None,
#   'restaurants_delivery': True,
#   'restaurants_good_for_groups': None,
#   'restaurants_reservations': False,
#   'restaurants_table_service': True,
#   'restaurants_take_out': True,
#   'waitlist_reservation': None,
#   'wi_fi': None,
#   'outdoor_seating': True,
#   'liked_by_vegans': None,
#   'liked_by_vegetarians': None}}

# %% [markdown]
# Now we insert all of the documents to the shops collections:
#
# `insert_many` is similar to `insert_one` but accept a list of document to insert.

# %%
result = shops_collection.insert_many(taco_shops['businesses'])
result
# Out:
# InsertManyResult([ObjectId('690e46bbf32eb86c842b88e6'), ObjectId('690e46bbf32eb86c842b88e7'), ObjectId('690e46bbf32eb86c842b88e8'), ObjectId('690e46bbf32eb86c842b88e9'), ObjectId('690e46bbf32eb86c842b88ea'), ObjectId('690e46bbf32eb86c842b88eb'), ObjectId('690e46bbf32eb86c842b88ec'), ObjectId('690e46bbf32eb86c842b88ed'), ObjectId('690e46bbf32eb86c842b88ee'), ObjectId('690e46bbf32eb86c842b88ef'), ObjectId('690e46bbf32eb86c842b88f0'), ObjectId('690e46bbf32eb86c842b88f1'), ObjectId('690e46bbf32eb86c842b88f2'), ObjectId('690e46bbf32eb86c842b88f3'), ObjectId('690e46bbf32eb86c842b88f4'), ObjectId('690e46bbf32eb86c842b88f5'), ObjectId('690e46bbf32eb86c842b88f6'), ObjectId('690e46bbf32eb86c842b88f7'), ObjectId('690e46bbf32eb86c842b88f8'), ObjectId('690e46bbf32eb86c842b88f9')], acknowledged=True)

# %% [markdown]
# Q1 [3 point]: Using find, list id (yelp id ) and name of all shops in the collection that are in Chicago. You need to use location.city

# %%
chicago_shops = shops_collection.find(
    {"location.city": "Chicago"},
    {"id": 1, "name": 1}
)

for shop in chicago_shops:
    print(shop)
# Out:
# {'_id': ObjectId('690e46bbf32eb86c842b88e6'), 'id': 'CADdsveMbJY-x_PFrsCkQw', 'name': 'El Tragon Taqueria'}
# {'_id': ObjectId('690e46bbf32eb86c842b88e7'), 'id': 'HiCXpGgxqjHPIlLyoZ06yw', 'name': 'Carniceria Maribel'}
# {'_id': ObjectId('690e46bbf32eb86c842b88e8'), 'id': 'Gr42JZ9GsKaESW-864rwFQ', 'name': 'Tepalcates'}
# {'_id': ObjectId('690e46bbf32eb86c842b88e9'), 'id': 'VNTJYUiOj6hD2Uac_prtPQ', 'name': 'Taqueria Chingon'}
# {'_id': ObjectId('690e46bbf32eb86c842b88ea'), 'id': '0Zu5S3zJvLC1Ve7kGAttDQ', 'name': 'Bárbaro Taquería'}
# {'_id': ObjectId('690e46bbf32eb86c842b88eb'), 'id': '-HqkUZg3tu-ZAV1RhdzXHQ', 'name': 'Tacotlan'}
# {'_id': ObjectId('690e46bbf32eb86c842b88ec'), 'id': 'oxJFCIVL9oQcmSIVSOBYew', 'name': 'Taco El Jalisciense'}
# {'_id': ObjectId('690e46bbf32eb86c842b88ed'), 'id': 'Yzs5dkjw3hEkM00RgBwNag', 'name': 'Taco Loco Of Pilsen'}
# {'_id': ObjectId('690e46bbf32eb86c842b88ee'), 'id': 'BGTumAF6UxyE-TrEB11WVg', 'name': 'Antique Taco '}
# {'_id': ObjectId('690e46bbf32eb86c842b88ef'), 'id': '_StOUGMGMmENR44zAEoDrA', 'name': 'Big Star'}
# {'_id': ObjectId('690e46bbf32eb86c842b88f0'), 'id': 'L12zP2yCgoKm_NLwW_HIDw', 'name': 'Quesabirria Jalisco'}
# {'_id': ObjectId('690e46bbf32eb86c842b88f1'), 'id': 'RIEypHKiSCZB5mJJJQNMcQ', 'name': 'Birrieria Zaragoza'}
# {'_id': ObjectId('690e46bbf32eb86c842b88f2'), 'id': 'Tkcjl_dPhBqx_8b59WByAA', 'name': 'Tacos & Burrito Express 3'}
# {'_id': ObjectId('690e46bbf32eb86c842b88f3'), 'id': 'jbCkRZUpzXcG1PYbgiby4g', 'name': 'Carnicerias Guanajuato'}
# {'_id': ObjectId('690e46bbf32eb86c842b88f4'), 'id': '0eMo-MeawM-tmbwpzv3rDg', 'name': 'Carnitas Uruapan'}
# {'_id': ObjectId('690e46bbf32eb86c842b88f5'), 'id': 'RI_TzjULvOknWecEq8cBQA', 'name': 'Taquizas Valdez'}
# {'_id': ObjectId('690e46bbf32eb86c842b88f6'), 'id': 'cO0DycIvBZ2Gwk2j2DJAOA', 'name': 'Don Pez Tacos Cantina'}
# {'_id': ObjectId('690e46bbf32eb86c842b88f7'), 'id': 'nTL9tlTqGr5-J68W-3Szww', 'name': 'Taqueria Traspasada'}
# {'_id': ObjectId('690e46bbf32eb86c842b88f8'), 'id': 'JgdQlqkP0cUq9Bq4_iSTPQ', 'name': "Dona Naty's Tacos"}
# {'_id': ObjectId('690e46bbf32eb86c842b88f9'), 'id': 'mzdaPepjOxUCqA7AwOr7kQ', 'name': 'Taqueria Mazamitla'}

# %% [markdown]
# Note that in the above documents 'id' is the yelp id for the document and '_id' is the MonogoDB id for the document.

# %%
#check  one review for one shop to see the structure:
reviews = yelp_api.reviews_query(id = 'htKi45T3U08n8FoHgTmLwg');
print(reviews['reviews'][0])
# Out:
# {'id': 'fEyRvZmfKOlhx5GAdNoSJw', 'url': 'https://www.yelp.com/biz/onions-and-cilantro-chicago?adjust_creative=xa8hs_B5jAwIuyuEtG_r0g&hrid=fEyRvZmfKOlhx5GAdNoSJw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=xa8hs_B5jAwIuyuEtG_r0g', 'text': "Our family's favorite Mexican food!  We order carry-out chicken and steak burritos from Onions and Cilantro a couple times a month.  Very clean and friendly...", 'rating': 5, 'time_created': '2025-10-30 15:40:17', 'user': {'id': 'bTd-1CglL6Ze4hrMvoNmJA', 'profile_url': 'https://www.yelp.com/user_details?userid=bTd-1CglL6Ze4hrMvoNmJA', 'image_url': 'https://s3-media0.fl.yelpcdn.com/photo/LBYEiYW1COl2P9Zu71_XNg/o.jpg', 'name': 'Laura T.'}}

# %% [markdown]
# Now for each document in the shop query, we use yelp to retrieve the reviews  and insert them to reviews collection at MongoDB. Reviews do not have shop name and the title, so add them to the reviews.

# %%
inserted_review = 0;
chicago_shops = shops_collection.find({}, {"id":1, "name":1})
for shop in chicago_shops:
  shop_id = shop['id'];
  shop_name = shop['name'];
  reviews = yelp_api.reviews_query(id = shop_id)
  for review in reviews['reviews']:
    review['shop_id'] = shop_id;
    review['shop_name'] = shop_name;
    reviews_collection.insert_one(review);
    inserted_review += 1;

print("Inserted ", inserted_review , " reviews into the reviews collection");
# Out:
# Inserted  140  reviews into the reviews collection

# %% [markdown]
# Q2: [4 points] Find all the reviews with the rating of greater than or equal to 4.5. Only keep the name of the shop, text, and rating (hint: use projection).

# %%
results = reviews_collection.find(
    {"rating": {"$gte": 4.5}},
    {"shop_name": 1, "text": 1, "rating": 1, "_id": 0}
)

for r in results:
    print(r)
# Out:
# {'text': 'Food: Amazing!! Very authentic and has a lot of flavor. My family got the chicken quesadillas and steak burrito. They were both delicious.\n\nService:...', 'rating': 5, 'shop_name': 'El Tragon Taqueria'}
# {'text': 'For the best tacos in Chicago - look no further! \nWe were blown away by the food at El Tragón. The quesabirria and carne asada were outstanding, and the...', 'rating': 5, 'shop_name': 'El Tragon Taqueria'}
# {'text': 'Best tacos in Chicago, no competition! Truly a hidden gem and a place I take a lot of pride bringing friends and family to, all who absolutely love it!...', 'rating': 5, 'shop_name': 'El Tragon Taqueria'}
# {'text': 'The services was so quick! I ordered the rice beans with three tacos. I chose asada, pollo and al pastor. My favorite was the pollo taco it was flavorful....', 'rating': 5, 'shop_name': 'El Tragon Taqueria'}
# {'text': 'Staff so nice and welcoming!! Food was delicious, loved the asada burrito and all of the salsas were tasty. Clean restaurant and servers took plates when we...', 'rating': 5, 'shop_name': 'El Tragon Taqueria'}
# {'text': 'The food is amazing very delicious. The birria was excellent as well as the chips and salsa.', 'rating': 5, 'shop_name': 'El Tragon Taqueria'}
# {'text': "My beef with the New York City taco scene is biblical. I'm so tired of paying $5+ for a one bite taco. It's against the whole ethos of the taco. The humble...", 'rating': 5, 'shop_name': 'Carniceria Maribel'}
# {'text': 'Such good tacos and great energy! \n\nThe flavors were spot on, especially the ribeye taco, which was cooked to perfection. You get to choose two veggies for...', 'rating': 5, 'shop_name': 'Carniceria Maribel'}
# {'text': 'Admittedly, I was solidly hungry but when our tacos arrived (sitting in the back of a corner store/tiny grocery store - you order at the back and then pay...', 'rating': 5, 'shop_name': 'Carniceria Maribel'}
# {'text': "No atmosphere. It's the back end of a Pilsen bodega but of course that's where you always get the good stuff. \nWe had 4 tacos - asada, al pastor, lengua,...", 'rating': 5, 'shop_name': 'Carniceria Maribel'}
# {'text': 'Great service, even better food. Drinks were also really good. Steak burrito was really good. Also had great veggie options for my gf.', 'rating': 5, 'shop_name': 'Tepalcates'}
# {'text': "This is not by where I live and I will go out of the way to get here every month. \n\nUnassuming little storefront from the outside, and you're immediately...", 'rating': 5, 'shop_name': 'Tepalcates'}
# {'text': "Went here for the first time after a friend insisted it's the best tacos he's ever had. The owner was super nice and first asked us if we had been before....", 'rating': 5, 'shop_name': 'Tepalcates'}
# {'text': 'My fiancé came here by chance, and he came home raving about the octopus taco. He said they recommended it, so the whole table he was with all ordered it....', 'rating': 5, 'shop_name': 'Tepalcates'}
# {'text': 'This is my new go to for Mexican in Chicago \n\nWe were first timers and to the owner was nice enough to let us try all the drinks (guava, Mexican lemonade,...', 'rating': 5, 'shop_name': 'Tepalcates'}
# {'text': 'The service is really what sets this restaurant apart! The owner was SO nice and friendly. The food was incredible as well, as soon as I got home I was...', 'rating': 5, 'shop_name': 'Tepalcates'}
# {'text': "I was visiting Chicago and was recommended to try this place by a local. It's right in Fulton market and not too far from the subway stop. I walked in and...", 'rating': 5, 'shop_name': 'Taqueria Chingon'}
# {'text': 'On the pricier side but excellent tacos. Much better than most. If you love tacos like me its definitely worth the money and worth the visit because great...', 'rating': 5, 'shop_name': 'Taqueria Chingon'}
# {'text': "Went to Taqueria Chingon while I was in town, I got a couple different tacos and they were delicious. The service and ambiance are nice, it's a new location...", 'rating': 5, 'shop_name': 'Taqueria Chingon'}
# {'text': "I'm used to paying $4-$5 for a taco, so when I saw prices ranging from $6-$9 at Taqueria Chingon, I expected the quality to match--and to my pleasant...", 'rating': 5, 'shop_name': 'Taqueria Chingon'}
# {'text': 'One of my favorite spots in the city. Amazing food with great music always playing. The drinks are on point and their seasonal food menu always has...', 'rating': 5, 'shop_name': 'Bárbaro Taquería'}
# {'text': 'as a tourist, i loved it here!!! the vibes here were immaculate - causal yet modern \n\neverything was amazing especially the flautas de pollos (chicken...', 'rating': 5, 'shop_name': 'Bárbaro Taquería'}
# {'text': "We ordered the carne asada tacos and they were a little small, so I definitely recommend ordering 2, but they were delicious. There wasn't any room to sit...", 'rating': 5, 'shop_name': 'Bárbaro Taquería'}
# {'text': "What distinguishes truly great Mexican food is freshness and a precise balance of flavors, and Barbaro continues to excel in both. I never thought I'd love...", 'rating': 5, 'shop_name': 'Bárbaro Taquería'}
# {'text': 'Man, I was introduced to this restaurant at the "Taste of Chicago" -2023-\nThe restaurant is very popular especially on the weekends. The service & selection...', 'rating': 5, 'shop_name': 'Tacotlan'}
# {'text': "I got the 3 quesabirria tacos with consumme and it was amazing! I've been wanting to try for a long time, I ended up ordering on Ubereats. They had a happy...", 'rating': 5, 'shop_name': 'Tacotlan'}
# {'text': 'Tacos and burritos are delicious but my favorite is the tilapia dinner. I could eat it everyday. Always get the guacamole. Been a customer for years....', 'rating': 5, 'shop_name': 'Taco El Jalisciense'}
# {'text': 'Food always good and service is always welcoming. Lemme get 10 tacos, some pico and a mix drink I love it here', 'rating': 5, 'shop_name': 'Taco El Jalisciense'}
# {'text': 'The BEST Mexican taco and burritos in the WORLD!!!! They have the best family friendly establishment and excellent customer service. They feel like family...', 'rating': 5, 'shop_name': 'Taco El Jalisciense'}
# {'text': 'Food is great.\n\nOnline ordering for pickup/delivery and being open on weekends would be a plus.', 'rating': 5, 'shop_name': 'Taco El Jalisciense'}
# {'text': "Some of the best tacos we've had in Chicago and our kids love their chicken quesadillas. My favorite is their Al pastor and asada. Everything we've ordered...", 'rating': 5, 'shop_name': 'Taco El Jalisciense'}
# {'text': "Was driving by and hungry... after seeing all the great reviews, had to stop in.   It's a cute little counter service taqueria with 2-3 tables and a few bar...", 'rating': 5, 'shop_name': 'Taco El Jalisciense'}
# {'text': "No frills but a lot of flavors. Haven't had a bad experience. Go earlier for his tacos de cabeza.", 'rating': 5, 'shop_name': 'Taco Loco Of Pilsen'}
# {'text
'shop_name': 'Don Pez Tacos Cantina'}
# {'text': "New favorite restaurant!!!!!! I can't say enough good things about this place. It's very tiny, so not best for a big group. They have the cutest little...", 'rating': 5, 'shop_name': 'Don Pez Tacos Cantina'}
# {'text': "It's small inside but they do have outdoor seating. And the food is worth the wait.\n\nWe ordered the dorados, the prime rib tacos and guacamole (with chips)....", 'rating': 5, 'shop_name': 'Don Pez Tacos Cantina'}
# {'text': 'Best skinny margaritas in Lincoln park. Gisele and Sofia made our first time here a great experience. We will be back.', 'rating': 5, 'shop_name': 'Don Pez Tacos Cantina'}
# {'text': 'Amazing service.  The drinks were made to perfection.   Pozole is authentic. Chips, salsa and guacamole were on point.  Giselle and Sofia were amazing and...', 'rating': 5, 'shop_name': 'Don Pez Tacos Cantina'}
# {'text': "I'm a mexican from Los Angeles. Great meat, owner was polite along with the cooks. Must go!", 'rating': 5, 'shop_name': 'Taqueria Traspasada'}
# {'text': 'Terrific service and great taste. No complaints!\n\nThe folks behind the counter were extremely nice. I ordered 3 tacos, and in addition to those and a salsa,...', 'rating': 5, 'shop_name': 'Taqueria Traspasada'}
# {'text': 'This is a hidden gem! I am at a loss of words. All I can say is come and see for yourself. \nTorta - Pastor PHENOMENAL\nTorta - Asada AMAZING\nBirria Soup...', 'rating': 5, 'shop_name': 'Taqueria Traspasada'}
# {'text': 'We had the asada torta and tacos- both were amazing. The seating area is very clean, and the staff were incredibly friendly and chatting with us about the...', 'rating': 5, 'shop_name': "Dona Naty's Tacos"}
# {'text': 'Great spot in West Town for chilaquiles, big portion, steak on top, rice and beans. Dining in is pleasant as well, kind service.', 'rating': 5, 'shop_name': "Dona Naty's Tacos"}
# {'text': 'Had my first torta here and it was soo amazing!!! Super nice staff and great prices. A must stop when on Chicago Ave.', 'rating': 5, 'shop_name': "Dona Naty's Tacos"}
# {'text': "Our go to taco joint in the neighborhood. Always solid. Normally get pastor, steak, tongue and tenderloin. Burritos are perfect size. I don't like that they...", 'rating': 5, 'shop_name': "Dona Naty's Tacos"}
# {'text': 'Pase aquí porque se me antojo unos tacos para el almuerzo. El restauran esta simple y limpio. Le gente eran amables y me ayudaron escoger tacos de tripa, al...', 'rating': 5, 'shop_name': "Dona Naty's Tacos"}
# {'text': "Consistent, quick and delicious! I've had tacos and burritos from Dona Naty's and they're always good. My favorites are the Al pastor and steak! Great spot...", 'rating': 5, 'shop_name': "Dona Naty's Tacos"}
# {'text': "This place has some of the best tacos I've had. And the pozole?...fire. I finally found a pozole that comes close to my grandma's..and that's saying a lot,...", 'rating': 5, 'shop_name': 'Taqueria Mazamitla'}
# {'text': 'I have been to this restaurant a few times now and it has never disappointed me. In the past I have ordered the quesabirria con consomé, churros, and all...', 'rating': 5, 'shop_name': 'Taqueria Mazamitla'}
# {'text': "Loved this place. Worth the train ride and walk. Like a home cooked meal.\nBeans were damn good. I had steak, my friend had tacos. We're coming back soon.", 'rating': 5, 'shop_name': 'Taqueria Mazamitla'}
# {'text': 'This place is a no frills authentic hole in the wall Mexican restaurant. I got the birria taco special and horchata and neither disappointed. Great food at...', 'rating': 5, 'shop_name': 'Taqueria Mazamitla'}
# {'text': "Came once yesterday Tuesday 8th of April and then the next day Wednesday the 9th. BEST TACOS BEST STEAK HANDS DOWN GOOD MEXICAN FOOD.\n\nI'm Mexican myself...", 'rating': 5, 'shop_name': 'Taqueria Mazamitla'}
# {'text': "First off it's BYOB! Street parking is tricky and you can't park next door at the 7/11 parking lot unless you want to get booted. Now that is out of the...", 'rating': 5, 'shop_name': 'Taqueria Mazamitla'}

# %% [markdown]
# Q3 [4 points]: using `time_created` field in the reviews, find of all reviews that have been entered in 2024 (after '2024-01-01)'. Only keep the shop_name, text, rating, and time_created.

# %%
results = reviews_collection.find(
    {"time_created": {"$gte": "2024-01-01"}},
    {"shop_name": 1, "text": 1, "rating": 1, "time_created": 1, "_id": 0}
)

for r in results:
    print(r)
# Out:
# {'text': 'Food: Amazing!! Very authentic and has a lot of flavor. My family got the chicken quesadillas and steak burrito. They were both delicious.\n\nService:...', 'rating': 5, 'time_created': '2025-07-07 20:31:42', 'shop_name': 'El Tragon Taqueria'}
# {'text': 
# {'text': "This is not by where I live and I will go out of the way to get here every month. \n\nUnassuming little storefront from the outside, and you're immediately...", 'rating': 5, 'time_created': '2025-10-18 06:32:10', 'shop_name': 'Tepalcates'}
# {'text': 'We enjoyed our meals, the dining room has a pleasant atmosphere, and I also enjoyed all the sunlight coming through their many windows!  \nWait staff was...', 'rating': 4, 'time_created': '2025-10-23 09:37:20', 'shop_name': 'Tepalcates'}
# {'text': "Went here for the first time after a friend insisted it's the best tacos he's ever had. The owner was super nice and first asked us if we had been before....", 'rating': 5, 'time_created': '2025-08-26 21:05:13', 'shop_name': 'Tepalcates'}
# {'text': 'My fiancé came here by chance, and he came home raving about the octopus taco. He said they recommended it, so the whole table he was with all ordered it....', 'rating': 5, 'time_created': '2025-09-18 17:03:56', 'shop_name': 'Tepalcates'}
# {'text': 'This is my new go to for Mexican in Chicago \n\nWe were first timers and to the owner was nice enough to let us try all the drinks (guava, Mexican lemonade,...', 'rating': 5, 'time_created': '2025-08-17 19:26:38', 'shop_name': 'Tepalcates'}
# {'text': 'The service is really what sets this restaurant apart! The owner was SO nice and friendly. The food was incredible as well, as soon as I got home I was...', 'rating': 5, 'time_created': '2025-10-25 19:01:44', 'shop_name': 'Tepalcates'}
# {'text': "I was visiting Chicago and was recommended to try this place by a local. It's right in Fulton market and not too far from the subway stop. I walked in and...", 'rating': 5, 'time_created': '2025-10-15 15:57:40', 'shop_name': 'Taqueria Chingon'}
# {'text': 'I went to the bucktown location a few times before it closed and this was my first time at the newly opened west loop location!\nTacos were great as usual. I...', 'rating': 4, 'time_created': '2025-10-10 14:48:24', 'shop_name': 'Taqueria Chingon'}
# {'text': 'Ambiance - casual, offers indoor and outdoor seating, open seating - you order and find your own table \nService - tacos took about 10-15 min\nFood - asada...', 'rating': 4, 'time_created': '2025-10-09 18:24:06', 'shop_name': 'Taqueria Chingon'}
# {'text': 'On the pricier side but excellent tacos. Much better than most. If you love tacos like me its definitely worth the money and worth the visit because great...', 'rating': 5, 'time_created': '2025-09-17 17:25:40', 'shop_name': 'Taqueria Chingon'}
# {'text': 'Very tasty food! Excellent variety and combination of interesting flavors. Since moving to this new location, there are plenty of seats indoor and outdoor....', 'rating': 4, 'time_created': '2025-09-12 13:54:36', 'shop_name': 'Taqueria Chingon'}
# {'text': "Went to Taqueria Chingon while I was in town, I got a couple different tacos and they were delicious. The service and ambiance are nice, it's a new location...", 'rating': 5, 'time_created': '2025-07-09 15:36:54', 'shop_name': 'Taqueria Chingon'}
# {'text': "I'm used to paying $4-$5 for a taco, so when I saw prices ranging from $6-$9 at Taqueria Chingon, I expected the quality to match--and to my pleasant...", 'rating': 5, 'time_created': '2025-07-24 19:02:55', 'shop_name': 'Taqueria Chingon'}
# {'text': 'One of my favorite spots in the city. Amazing food with great music always playing. The drinks are on point and their seasonal food menu always has...', 'rating': 5, 'time_created': '2025-09-23 11:12:24', 'shop_name': 'Bárbaro Taquería'}
# {'text': 'as a tourist, i loved it here!!! the vibes here were immaculate - causal yet modern \n\neverything was amazing especially the flautas de pollos (chicken...', 'rating': 5, 'time_created': '2025-07-28 20:41:31', 'shop_name': 'Bárbaro Taquería'}
# {'text': 'Felt like trying a different taco place before a show. Happy I pulled the trigger on Barbaro. I kept it simple , I got the sopitos to start and two...', 'rating': 4, 'time_created': '2025-10-04 18:20:14', 'shop_name': 'Bárbaro Taquería'}
# {'text': 'If you are looking for a slightly modern Mexican dining experience, you have to check out Bárbaro Taquería. The ambiance is really nice with a contemporary...', 'rating': 4, 'time_created': '2025-05-25 08:18:04', 'shop_name': 'Bárbaro Taquería'}
# {'text': "We ordered the carne asada tacos and they were a little small, so I definitely recommend ordering 2, but they were delicious. There wasn't any room to sit...", 'rating': 5, 'time_created': '2025-09-28 09:57:39', 'shop_name': 'Bárbaro Taquería'}
# {'text': "What distinguishes truly great Mexican food is freshness and a precise balance of flavors, and Barbaro continues to excel in both. I never thought I'd love...", 'rating': 5, 'time_created': '2025-10-07 12:29:28', 'shop_name': 'Bárbaro Taquería'}
# {'text': 'Love coming in for the great food and drinks. Definitely always get the oreo tres leche cake. Being from southern California, this seems to be the...', 'rating': 4, 'time_created': '2025-10-23 21:35:42', 'shop_name': 'Bárbaro Taquería'}
# {'text': 'Man, I was introduced to this restaurant at the "Taste of Chicago" -2023-\nThe restaurant is very popular especially on the weekends. The service & selection...', 'rating': 5, 'time_created': '2025-09-04 05:12:21', 'shop_name': 'Tacotlan'}
# {'text': 'We went on Tuesday, October 21st around 4pm.\n\nFood was fresh, hot and delicious! \n\nService was friendly, prompt and efficient\n\nAmbiance feels authentic and...', 'rating': 4, 'time_created': '2025-10-21 14:41:15', 'shop_name': 'Tacotlan'}
# {'text': 'I had this restaurant on my list to try. The food was pretty good. I had one chicken, steak, shrimp. 3 quesabirrias, topped with onion and cilantro and...', 'rating': 3, 'time_created': '2025-09-27 22:45:36', 'shop_name': 'Tacotlan'}
# {'text': 'We decided to go try out Tacotlán after seeing it all over TikTok! \n\nThe inside is busy, but we were sat immediately. They have an extensive birria menu...', 'rating': 4, 'time_created': '2025-08-14 08:46:29', 'shop_name': 'Tacotlan'}
# {'text': 'We ordered takeout from Tacotlan and it was pretty good. I heard it was a bit better before, nevertheless, I enjoyed my meal. I ordered the birria taco...', 'rating': 4, 'time_created': '2025-10-25 20:24:14', 'shop_name': 'Tacotlan'}
# {'text': 'Place was really nice and welcoming but the food was bit my favorite, I had birrias tacos just because I saw a lot of reviews on it and it was not worth it...', 'rating': 3, 'time_created': '2025-11-02 08:33:40', 'shop_name': 'Tacotlan'}
# {'text': "I got the 3 quesabirria tacos with consumme and it was amazing! I've been wanting to try for a long time, I ended up ordering on Ubereats. They had a happy...", 'rating': 5, 'time_created': '2025-09-18 14:17:36', 'shop_name': 'Tacotlan'}
# {'text': 'Tacos and burritos are delicious but my favorite is the tilapia dinner. I could eat it everyday. Always get the guacamole. Been a customer for years....', 'rating': 5, 'time_created': '2025-09-15 16:14:19', 'shop_name': 'Taco El Jalisciense'}
# {'text': "If you're unsure if you should where to get tacos look NO FURTHER!!\n\nLOVE antique taco!! The steak is always my fav but this time I tried the shrimp taco...", 'rating': 5, 'time_created': '2024-09-10 12:35:11', 'shop_name': 'Antique Taco '}
# {'text': 'Service is really good and fast. \n You have to buy chips and salsa \nThere is a out door patio super chill spot.  The steak taste like pulled beef not steak....', 'rating': 4, 'time_created': '2025-10-05 13:45:38', 'shop_name': 'Big Star'}
# {'text': 'Big star gets a lot of hate for being a tex/mex place, and it is not really Tex mex, more chain style Mexican food. And I have lived in Austin. \n\nWe came...', 'rating': 3, 'time_created': '2025-08-28 05:37:48', 'shop_name': 'Big Star'}
# {'text': 'Birria tacos - so good. Comes in a pair of 2. \n\nWalking taco - so good and so fun. \n\nChips and queso - solid.\n\nFish taco is so bomb. Mine was very hot and...', 'rating': 5, 'time_created': '2025-06-29 09:16:28', 'shop_name': 'Big Star'}
# {'text': 'Staple taco joint in Wicker Park with a sweet patio. This places always has a lot of activity even in the winter. My husband frequents this restaurant more...', 'rating': 4, 'time_created': '2025-06-02 20:30:45', 'shop_name': 'Big Star'}
# {'text': 'Great spot for Mexican food and beer. Came here on a busy Saturday afternoon but were still seated right away. Staff was really friendly and welcoming. My...', 'rating': 5, 'time_created': '2025-07-24 06:40:53', 'shop_name': 'Big Star'}
# {'text': 'Really love the outdoor patio vibes and fun decor. The margaritas are super yummy and I love that you can pick and choose different flavor options. The...', 'rating': 3, 'time_created': '2025-06-27 09:08:03', 'shop_name': 'Big Star'}
# {'text': 'Was a hot summer day and we just arrived to wicker park to shop. This place had lots of seats open and we got our food ordered and served very quickly....', 'rating': 4, 'time_created': '2025-07-05 12:40:54', 'shop_name': 'Big Star'}
# {'text': 'It took about 20-30 minutes for the food to arrive. But when it did the food was amazing. I believe it was worth the wait. There was a small line when we...', 'rating': 4, 'time_created': '2025-09-23 17:37:55', 'shop_name': 'Quesabirria Jalisco'}
# {'text': 'Yum! Yum! Yum!\nI came in for my serving visit not realizing I had been here before--and what a treat it was! We ordered six beef birria tacos and two birria...', 'rating': 5, 'time_created': '2025-09-13 20:00:08', 'shop_name': 'Quesabirria Jalisco'}
# {'text': 'Where do I start.. \n\nI had high hopes for this place. I came in at opening (11:30 am) and it took nearly 20 minutes to receive my 3 tacos. You order at the...', 'rating': 2, 'time_created': '2025-07-13 19:58:49', 'shop_name': 'Quesabirria Jalisco'}
# {'text': "The food was hefty and salty. I'm used to birria compote having a smoother comforting taste but this was pure salt. The service was great though, just one...", 'rating': 3, 'time_created': '2025-09-04 17:10:45', 'shop_name': 'Quesabirria Jalisco'}
# {'text': "The best quesabirria tacos ever. The strawberry horchata was so delicious too. The consome had sooo much flavor and it made everything 100x better. I've...", 'rating': 5, 'time_created': '2025-10-26 09:32:35', 'shop_name': 'Quesabirria Jalisco'}
# {'text': "I've said it once and I'll say it again, once you've had goat birria for breakfast on a street corner in Jalisco everything else pales in comparison. That...", 'rating': 3, 'time_created': '2024-11-30 20:31:10', 'shop_name': 'Quesabirria Jalisco'}
 'shop_name': 'Carnicerias Guanajuato'}
# {'text': 'The food here is pretty good. It tastes delicious and authentic. The ambience is lovely as they do get busy so the customer service is just about getting...', 'rating': 4, 'time_created': '2025-11-01 13:15:02', 'shop_name': 'Carnicerias Guanajuato'}
# {'text': 'There is a great Mexican deli inside this supermarket that has amazing street tacos! This place was busy but the food came out quickly and it looked like...', 'rating': 5, 'time_created': '2024-11-04 06:06:05', 'shop_name': 'Carnicerias Guanajuato'}
# {'text': "Order the chicken unless you like well done steak.  The food is super affordable and the portions are large hearty.  I'm a regular the tacos have like...", 'rating': 5, 'time_created': '2025-04-28 06:44:25', 'shop_name': 'Carnicerias Guanajuato'}
# {'text': 'Love this taco joint tucked inside the grocery store. Fair prices and pretty tasty tacos, plus I also recommend the fresh juices (papaya is my go-to)....', 'rating': 5, 'time_created': '2025-04-13 11:57:54', 'shop_name': 'Carnicerias Guanajuato'}
# {'text': 'Overall Thoughts: Carnicerias Guanajuato is a nice Mexican grocery store in the Wicker area with a little restaurant tucked in the back. It carries a solid...', 'rating': 4, 'time_created': '2024-01-14 14:11:09', 'shop_name': 'Carnicerias Guanajuato'}
# {'text': 'Carnicerias Guanajuato is a hidden gem that needs to be tried by the masses!  The hot sauce selection is by far superior than any other place I have...', 'rating': 5, 'time_created': '2024-06-23 16:18:58', 'shop_name': 'Carnicerias Guanajuato'}
# {'text': 'Took a ride from the northwest suburbs on July 4th after seeing this spot recommended by a YouTube influencer--and I have to say, it was definitely worth...', 'rating': 5, 'time_created': '2025-07-04 12:41:04', 'shop_name': 'Carnitas Uruapan'}
# {'text': "So... found out the hard way that this location is now to-go only! I'd been here pre-pandemic and remembered being able to dine in, so I was surprised to...", 'rating': 4, 'time_created': '2025-11-02 21:48:29', 'shop_name': 'Carnitas Uruapan'}
# {'text': 'Where to start? Everything was so good. \n\nWe got two daily specials for two people. I think one would have sufficed. So much food, so much deliciousness....', 'rating': 5, 'time_created': '2025-06-07 11:02:35', 'shop_name': 'Carnitas Uruapan'}
# {'text': "The spot is the go to for pork tacos. The place just oozes with the smells of pork. You can order pork by the pound or dressed up in tacos. They're super...", 'rating': 5, 'time_created': '2025-10-11 15:25:54', 'shop_name': 'Carnitas Uruapan'}
# {'text': 'Se te hace agua la boca en cuanto entras de como huele de bueno. I came here at the recommendation of a friend, and being from Michoacán I had high...', 'rating': 5, 'time_created': '2024-08-25 11:41:41', 'shop_name': 'Carnitas Uruapan'}
# {'text': "Carnitas was amazing here! Tortillas and chicharrones made in house. This is the original location so it's more of a take out location. If you want a dine...", 'rating': 4, 'time_created': '2025-03-21 14:45:17', 'shop_name': 'Carnitas Uruapan'}
# {'text': 'We walked in and surprisingly the place was pretty empty at around 3pm. This was great though, because it allowed us to take our time to figure out exactly...', 'rating': 4, 'time_created': '2024-10-30 14:20:53', 'shop_name': 'Carnitas Uruapan'}
# {'text': "This place ROCKS. It's all awesome but huge ups to the tacos, especially the mushroom taco. Try it all - delicious and keep in mind one meal is definitely...", 'rating': 5, 'time_created': '2025-05-10 09:24:40', 'shop_name': 'Taquizas Valdez'}
# {'text': "I've had their tacos and a burrito. One of the best burritos in town, by a long shot. All the flavors are elevated. You can tell how much effort went into...", 'rating': 5, 'time_created': '2025-10-22 12:43:51', 'shop_name': 'Taquizas Valdez'}
# %% [markdown]
# Ok, now let's find the average rating for each shop

# %%
#To keep the the shop name, we can use "$first" which keep the first value of the requested field in all of the documents in the group.
#Since all of the documents would have the same shop name (we group them on shop_id), shop_name would be the same and $first gets the correct shop name

pipeline = [
    {
        "$group": {
            "_id": "$shop_id",
            "averageRating": { "$avg": "$rating" },
            "shop_name": { "$first": "$shop_name" }
        }
    },
    {
        "$project": {
            "shop_id": "$_id",
            "shop_name": 1,
            "averageRating": 1
        }
    }

]

result = reviews_collection.aggregate(pipeline)

# Print results
for doc in result:
    print(doc)
# Out:
# {'_id': 'BGTumAF6UxyE-TrEB11WVg', 'averageRating': 4.142857142857143, 'shop_name': 'Antique Taco ', 'shop_id': 'BGTumAF6UxyE-TrEB11WVg'}
# {'_id': 'Tkcjl_dPhBqx_8b59WByAA', 'averageRating': 5.0, 'shop_name': 'Tacos & Burrito Express 3', 'shop_id': 'Tkcjl_dPhBqx_8b59WByAA'}
# {'_id': 'VNTJYUiOj6hD2Uac_prtPQ', 'averageRating': 4.571428571428571, 'shop_name': 'Taqueria Chingon', 'shop_id': 'VNTJYUiOj6hD2Uac_prtPQ'}
# {'_id': 'cO0DycIvBZ2Gwk2j2DJAOA', 'averageRating': 4.285714285714286, 'shop_name': 'Don Pez Tacos Cantina', 'shop_id': 'cO0DycIvBZ2Gwk2j2DJAOA'}
# {'_id': '-HqkUZg3tu-ZAV1RhdzXHQ', 'averageRating': 4.0, 'shop_name': 'Tacotlan', 'shop_id': '-HqkUZg3tu-ZAV1RhdzXHQ'}
# {'_id': 'HiCXpGgxqjHPIlLyoZ06yw', 'averageRating': 4.428571428571429, 'shop_name': 'Carniceria Maribel', 'shop_id': 'HiCXpGgxqjHPIlLyoZ06yw'}
# {'_id': 'RIEypHKiSCZB5mJJJQNMcQ', 'averageRating': 5.0, 'shop_name': 'Birrieria Zaragoza', 'shop_id': 'RIEypHKiSCZB5mJJJQNMcQ'}
# {'_id': 'Gr42JZ9GsKaESW-864rwFQ', 'averageRating': 4.857142857142857, 'shop_name': 'Tepalcates', 'shop_id': 'Gr42JZ9GsKaESW-864rwFQ'}
# {'_id': 'jbCkRZUpzXcG1PYbgiby4g', 'averageRating': 4.714285714285714, 'shop_name': 'Carnicerias Guanajuato', 'shop_id': 'jbCkRZUpzXcG1PYbgiby4g'}
# {'_id': 'Yzs5dkjw3hEkM00RgBwNag', 'averageRating': 4.857142857142857, 'shop_name': 'Taco Loco Of Pilsen', 'shop_id': 'Yzs5dkjw3hEkM00RgBwNag'}
# {'_id': '0eMo-MeawM-tmbwpzv3rDg', 'averageRating': 4.571428571428571, 'shop_name': 'Carnitas Uruapan', 'shop_id': '0eMo-MeawM-tmbwpzv3rDg'}
# {'_id': 'nTL9tlTqGr5-J68W-3Szww', 'averageRating': 4.285714285714286, 'shop_name': 'Taqueria Traspasada', 'shop_id': 'nTL9tlTqGr5-J68W-3Szww'}
# {'_id': '_StOUGMGMmENR44zAEoDrA', 'averageRating': 4.0, 'shop_name': 'Big Star', 'shop_id': '_StOUGMGMmENR44zAEoDrA'}
# {'_id': 'JgdQlqkP0cUq9Bq4_iSTPQ', 'averageRating': 4.571428571428571, 'shop_name': "Dona Naty's Tacos", 'shop_id': 'JgdQlqkP0cUq9Bq4_iSTPQ'}
# {'_id': 'oxJFCIVL9oQcmSIVSOBYew', 'averageRating': 4.714285714285714, 'shop_name': 'Taco El Jalisciense', 'shop_id': 'oxJFCIVL9oQcmSIVSOBYew'}
# {'_id': 'L12zP2yCgoKm_NLwW_HIDw', 'averageRating': 3.4285714285714284, 'shop_name': 'Quesabirria Jalisco', 'shop_id': 'L12zP2yCgoKm_NLwW_HIDw'}
# {'_id': '0Zu5S3zJvLC1Ve7kGAttDQ', 'averageRating': 4.571428571428571, 'shop_name': 'Bárbaro Taquería', 'shop_id': '0Zu5S3zJvLC1Ve7kGAttDQ'}
# {'_id': 'CADdsveMbJY-x_PFrsCkQw', 'averageRating': 4.857142857142857, 'shop_name': 'El Tragon Taqueria', 'shop_id': 'CADdsveMbJY-x_PFrsCkQw'}
# {'_id': 'RI_TzjULvOknWecEq8cBQA', 'averageRating': 4.571428571428571, 'shop_name': 'Taquizas Valdez', 'shop_id': 'RI_TzjULvOknWecEq8cBQA'}
# {'_id': 'mzdaPepjOxUCqA7AwOr7kQ', 'averageRating': 4.714285714285714, 'shop_name': 'Taqueria Mazamitla', 'shop_id': 'mzdaPepjOxUCqA7AwOr7kQ'}

# %% [markdown]
# Q4 [4 points]: Find the averate rating of each shop for the only reviews that have been entered in 2024, and return top 10 shops with highest average rating (all with one pipeline)

# %%
#Hint: you have to add a couple of stages to the previous pipline

pipeline = [
    {
        "$match": {
            "time_created": {"$gte": "2024-01-01"}
        }
    },
    {
        "$group": {
            "_id": "$shop_id",
            "averageRating": { "$avg": "$rating" },
            "shop_name": { "$first": "$shop_name" }
        }
    },
    {
        "$project": {
            "shop_id": "$_id",
            "shop_name": 1,
            "averageRating": 1
        }
    },

]

result = reviews_collection.aggregate(pipeline)

# Print results
for doc in result:
    print(doc)
# Out:
# {'_id': 'cO0DycIvBZ2Gwk2j2DJAOA', 'averageRating': 4.285714285714286, 'shop_name': 'Don Pez Tacos Cantina', 'shop_id': 'cO0DycIvBZ2Gwk2j2DJAOA'}
# {'_id': 'RI_TzjULvOknWecEq8cBQA', 'averageRating': 4.571428571428571, 'shop_name': 'Taquizas Valdez', 'shop_id': 'RI_TzjULvOknWecEq8cBQA'}
# {'_id': 'BGTumAF6UxyE-TrEB11WVg', 'averageRating': 4.142857142857143, 'shop_name': 'Antique Taco ', 'shop_id': 'BGTumAF6UxyE-TrEB11WVg'}
# {'_id': 'mzdaPepjOxUCqA7AwOr7kQ', 'averageRating': 4.714285714285714, 'shop_name': 'Taqueria Mazamitla', 'shop_id': 'mzdaPepjOxUCqA7AwOr7kQ'}
# {'_id': 'CADdsveMbJY-x_PFrsCkQw', 'averageRating': 4.857142857142857, 'shop_name': 'El Tragon Taqueria', 'shop_id': 'CADdsveMbJY-x_PFrsCkQw'}
# {'_id': 'oxJFCIVL9oQcmSIVSOBYew', 'averageRating': 5.0, 'shop_name': 'Taco El Jalisciense', 'shop_id': 'oxJFCIVL9oQcmSIVSOBYew'}
# {'_id': 'L12zP2yCgoKm_NLwW_HIDw', 'averageRating': 3.4285714285714284, 'shop_name': 'Quesabirria Jalisco', 'shop_id': 'L12zP2yCgoKm_NLwW_HIDw'}
# {'_id': '0Zu5S3zJvLC1Ve7kGAttDQ', 'averageRating': 4.571428571428571, 'shop_name': 'Bárbaro Taquería', 'shop_id': '0Zu5S3zJvLC1Ve7kGAttDQ'}
# {'_id': '_StOUGMGMmENR44zAEoDrA', 'averageRating': 4.0, 'shop_name': 'Big Star', 'shop_id': '_StOUGMGMmENR44zAEoDrA'}
# {'_id': 'JgdQlqkP0cUq9Bq4_iSTPQ', 'averageRating': 5.0, 'shop_name': "Dona Naty's Tacos", 'shop_id': 'JgdQlqkP0cUq9Bq4_iSTPQ'}
# {'_id': 'Gr42JZ9GsKaESW-864rwFQ', 'averageRating': 4.857142857142857, 'shop_name': 'Tepalcates', 'shop_id': 'Gr42JZ9GsKaESW-864rwFQ'}
# {'_id': 'Yzs5dkjw3hEkM00RgBwNag', 'averageRating': 4.833333333333333, 'shop_name': 'Taco Loco Of Pilsen', 'shop_id': 'Yzs5dkjw3hEkM00RgBwNag'}
# {'_id': 'RIEypHKiSCZB5mJJJQNMcQ', 'averageRating': 5.0, 'shop_name': 'Birrieria Zaragoza', 'shop_id': 'RIEypHKiSCZB5mJJJQNMcQ'}
# {'_id': 'jbCkRZUpzXcG1PYbgiby4g', 'averageRating': 4.714285714285714, 'shop_name': 'Carnicerias Guanajuato', 'shop_id': 'jbCkRZUpzXcG1PYbgiby4g'}
# {'_id': 'HiCXpGgxqjHPIlLyoZ06yw', 'averageRating': 4.428571428571429, 'shop_name': 'Carniceria Maribel', 'shop_id': 'HiCXpGgxqjHPIlLyoZ06yw'}
# {'_id': '-HqkUZg3tu-ZAV1RhdzXHQ', 'averageRating': 4.0, 'shop_name': 'Tacotlan', 'shop_id': '-HqkUZg3tu-ZAV1RhdzXHQ'}
# {'_id': '0eMo-MeawM-tmbwpzv3rDg', 'averageRating': 4.571428571428571, 'shop_name': 'Carnitas Uruapan', 'shop_id': '0eMo-MeawM-tmbwpzv3rDg'}
# {'_id': 'nTL9tlTqGr5-J68W-3Szww', 'averageRating': 4.2, 'shop_name': 'Taqueria Traspasada', 'shop_id': 'nTL9tlTqGr5-J68W-3Szww'}
# {'_id': 'Tkcjl_dPhBqx_8b59WByAA', 'averageRating': 5.0, 'shop_name': 'Tacos & Burrito Express 3', 'shop_id': 'Tkcjl_dPhBqx_8b59WByAA'}
# {'_id': 'VNTJYUiOj6hD2Uac_prtPQ', 'averageRating': 4.571428571428571, 'shop_name': 'Taqueria Chingon', 'shop_id': 'VNTJYUiOj6hD2Uac_prtPQ'}

# %%
client.close()
